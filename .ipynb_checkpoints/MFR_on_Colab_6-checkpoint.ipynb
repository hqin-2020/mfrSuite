# %%
import sys
import os
sys.path.insert(0,'drive/My Drive/current/BFI/MFR/mfrSuite2020')

os.chdir('drive/MyDrive/current/BFI/MFR/mfrSuite2020/')
# !bash install.sh
# Out:
# ...
# The MFR suite
# Questions: please contact Macro-Financial Modeling (MFR) Team at Becker Friedman Institute
# URL: https://bfi.uchicago.edu/mfm
# ...
# Starting installation process...
# ...
# Step 0: Install numba and pybind11
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 213 kB 5.0 MB/s
# ...
# Step 1: Install toolboxes to compute shock elasticities and stationary density
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing ./src/sdm
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# ...

# %%
# %cd SolvedModels
import non_log_prod_tests_ah_0135.py
# Out:
# /Users/haominqin/Dropbox/Mac/Documents/MFR/mfrSuite/SolvedModels
